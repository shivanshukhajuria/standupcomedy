# %% [markdown]
# Most Common Words

# %% [markdown]
# Analysis

# %% [markdown]
# Read in the document-term matrix

# %%
data = pd.read_pickle('data_clean.pkl')
data
# Out:
#                                                 transcript
# aziz     ♪ sometimes i feel so happy ♪ ♪ sometimes i fe...
# chris      ladies and gentlemen chris rock  yeah please...
# hannah   the following is the transcript of hannah gadb...
# kenny    make some noise for kenny sebastian oh my god ...
# kevin        its showtime honey babe im gone  coming al...
# nate      ♪ family ♪ ♪ singin in the kitchen ♪ ♪ family...
# norm     then people go goddamn at least hes not a hypo...
# russell    narrator ladies and gentlemen its start time...
# vir      i lost  of my mind its very freeing you should...
# whitney  ladies and gentlemen whitney cummings this is ...

# %%
import pandas as pd

data = pd.read_pickle('wordcount.pkl')
data = data.transpose()
data
# Out:
#               aziz  chris  hannah  kenny  kevin  nate  norm  russell  vir  \
# aaaaaa           0      0       0      2      0     0     0        0    0
# aah              1      0       0      0      0     0     0        0    0
# aaliyah          1      0       0      0      0     0     0        0    0
# abandoned        1      0       0      0      1     0     0        0    0
# abbreviation     0      0       0      0      0     0     1        0    0
# ...            ...    ...     ...    ...    ...   ...   ...      ...  ...
# zuckerberg       0      1       0      0      0     0     0        0    0
# zuckerfuck       0      1       0      0      0     0     0        0    0
# zuckerfucker     0      1       0      0      0     0     0        0    0
# zuckermother     0      2       0      0      0     0     0        0    0
# zuckzucker       0      1       0      0      0     0     0        0    0
#
#               whitney
# aaaaaa              0
# aah                 0
# ...

# %% [markdown]
# Find and print the top 30 words said by each comedian

# %%
topword = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    topword[c] = list(zip(top.index,top.values))
topword
# Out:
# {'aziz': [('like', 182),
#   ('know', 98),
#   ('just', 89),
#   ('im', 76),
#   ('uh', 74),
#   ('people', 71),
#   ('right', 68),
#   ('dont', 65),
#   ('cause', 43),
#   ('youre', 42),
#   ('yeah', 40),
#   ('oh', 38),
#   ('okay', 37),
#   ('think', 34),
#   ('got', 33),
#   ('thats', 32),
#   ('thing', 30),
#   ('hes', 30),
#   ('ive', 29),
#   ('gonna', 28),
#   ('stuff', 28),
#   ('way', 26),
#   ('say', 25),
#   ('time', 25),
#   ('white', 24),
#   ('really', 23),
#   ('little', 23),
#   ('lets', 22),
#   ('guys', 22),
#   ('guy', 22)],
#  'chris': [('like', 109),
#   ('man', 89),
#   ('know', 77),
#   ('right', 76),
#   ('thats', 70),
#   ('im', 69),
#   ('shit', 54),
#   ('got', 49),
#   ('fuck', 44),
#   ('just', 44),
#   ('ok', 43),
#   ('youre', 43),
#   ('god', 42),
#   ('dont', 38),
#   ('fucking', 38),
#   ('kids', 38),
#   ('people', 33),
#   ('think', 28),
#   ('need', 24),
#   ('gotta', 24),
#   ('black', 23),
#   ('tambourine', 22),
#   ('oh', 21),
# ...

# %% [markdown]
# Top 15 words said by each comedian

# %%
for comedian, top_words in topword.items():
    print(comedian)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# aziz
# like, know, just, im, uh, people, right, dont, cause, youre, yeah, oh, okay, think
# ---
# chris
# like, man, know, right, thats, im, shit, got, fuck, just, ok, youre, god, dont
# ---
# hannah
# just, like, im, know, dont, thats, right, fucking, ive, youre, bit, good, said, joke
# ---
# kenny
# like, im, just, guys, bro, dont, know, hey, yeah, nice, okay, thats, come, mom
# ---
# kevin
# like, im, dont, said, got, baby, shit, know, just, want, fucking, thats, man, time
# ---
# nate
# like, just, know, im, dont, thats, goes, mean, right, youre, hes, got, think, ive
# ---
# norm
# know, like, im, dont, just, thats, right, going, think, love, guy, ill, said, good
# ---
# russell
# like, know, im, dont, goes, said, just, going, youre, thats, got, people, right, indian
# ---
# vir
# like, just, know, shit, im, dont, thats, think, right, guys, did, youre, yeah, indian
# ---
# whitney
# like, just, im, know, going, thats, dont, women, guys, guy, got, think, youre, robot
# ---

# %% [markdown]
# Most common top words

# %%
from collections import Counter

words = []
for comedian in data.columns:
    top = [word for (word, count) in topword[comedian]]
    for t in top:
        words.append(t)      
words
# Out:
# ['like',
#  'know',
#  'just',
#  'im',
#  'uh',
#  'people',
#  'right',
#  'dont',
#  'cause',
#  'youre',
#  'yeah',
#  'oh',
#  'okay',
#  'think',
#  'got',
#  'thats',
#  'thing',
#  'hes',
#  'ive',
#  'gonna',
#  'stuff',
#  'way',
#  'say',
#  'time',
#  'white',
#  'really',
#  'little',
#  'lets',
#  'guys',
#  'guy',
#  'like',
#  'man',
#  'know',
#  'right',
#  'thats',
#  'im',
#  'shit',
#  'got',
#  'fuck',
#  'just',
#  'ok',
#  'youre',
#  'god',
#  'dont',
#  'fucking',
#  'kids',
#  'people',
#  'think',
#  'need',
#  'gotta',
#  'black',
#  'tambourine',
#  'oh',
#  'house',
#  'good',
#  'gonna',
#  'motherfucker',
#  'white',
#  'thing',
#  'cause',
#  'just',
#  'like',
#  'im',
#  'know',
#  'dont',
#  'thats',
#  'right',
#  'fucking',
#  'ive',
#  'youre',
#  'bit',
#  'good',
#  'said',
#  'joke',
#  'douglas',
#  'going',
#  'box',
#  'say',
#  'men',
#  'way',
#  'look',
#  'gonna',
#  'things',
#  'fuck',
#  'oh',
#  'did',
#  'autism',
#  'thing',
# ...

# %%
Counter(words).most_common()
# Out:
# [('like', 10),
#  ('know', 10),
#  ('just', 10),
#  ('im', 10),
#  ('right', 10),
#  ('dont', 10),
#  ('youre', 10),
#  ('thats', 10),
#  ('got', 9),
#  ('people', 8),
#  ('oh', 7),
#  ('going', 7),
#  ('think', 6),
#  ('thing', 6),
#  ('shit', 6),
#  ('fuck', 6),
#  ('yeah', 5),
#  ('say', 5),
#  ('time', 5),
#  ('guy', 5),
#  ('did', 5),
#  ('want', 5),
#  ('cause', 4),
#  ('gonna', 4),
#  ('guys', 4),
#  ('man', 4),
#  ('fucking', 4),
#  ('good', 4),
#  ('said', 4),
#  ('uh', 3),
#  ('okay', 3),
#  ('hes', 3),
#  ('ive', 3),
#  ('need', 3),
#  ('house', 3),
#  ('look', 3),
#  ('theres', 3),
#  ('way', 2),
#  ('white', 2),
#  ('little', 2),
#  ('ok', 2),
#  ('god', 2),
#  ('kids', 2),
#  ('hey', 2),
#  ('make', 2),
#  ('women', 2),
#  ('son', 2),
#  ('goes', 2),
#  ('mean', 2),
#  ('day', 2),
#  ('theyre', 2),
#  ('years', 2),
#  ('indian', 2),
#  ('india', 2),
#  ('stuff', 1),
#  ('really', 1),
#  ('lets', 1),
#  ('gotta', 1),
#  ('black', 1),
#  ('tambourine', 1),
# ...

# %%
add_stop_words = [word for word, count in Counter(words).most_common() if count > 5]
add_stop_words
# Out:
# ['like',
#  'know',
#  'just',
#  'im',
#  'right',
#  'dont',
#  'youre',
#  'thats',
#  'got',
#  'people',
#  'oh',
#  'going',
#  'think',
#  'thing',
#  'shit',
#  'fuck']

# %%
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

data_clean = pd.read_pickle('data_clean.pkl')

stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")

# %%
from wordcloud import WordCloud
wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2", max_font_size=150, random_state=42)

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

full_names = ['Aziz Ansari','Chris Rock','Hannah Gadsby','Kenny Sebastian','Kevin Hart','Nate Bargatze','Norm Macdonald','Russell Peters ','Vir Das','Whitney Cummings']

for index, comedian in enumerate(data.columns):
    wc.generate(data_clean.transcript[comedian])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(full_names[index])
    
plt.show()

# %% [markdown]
# Observations:
# 1. Vir Das has a lot of Indian audience because he says the word indian he talks about India
# 2. Whitney Cumming talks about women and hence is very popular among women

# %%
unique_list = []
for comedian in data.columns:
    uniques = data[comedian].to_numpy().nonzero()[0].size
    unique_list.append(uniques)

data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['comedian', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words')
data_unique_sort
# Out:
#            comedian  unique_words
# 1        Chris Rock          1054
# 6    Norm Macdonald          1071
# 3   Kenny Sebastian          1074
# 4        Kevin Hart          1181
# 7   Russell Peters           1213
# 5     Nate Bargatze          1221
# 0       Aziz Ansari          1333
# 9  Whitney Cummings          1385
# 8           Vir Das          1418
# 2     Hannah Gadsby          1547

# %%
total_list = []
for comedian in data.columns:
    totals = sum(data[comedian])
    total_list.append(totals)

run_times = [65, 64, 72, 60, 60, 60, 60, 67, 67, 59]

data_words['total_words'] = total_list
data_words['run_times'] = run_times
data_words['words_per_minute'] = data_words['total_words'] / data_words['run_times']

data_wpm_sort = data_words.sort_values(by='words_per_minute')
data_wpm_sort
# Out:
#            comedian  unique_words  total_words  run_times  words_per_minute
# 6    Norm Macdonald          1071         3146         60         52.433333
# 3   Kenny Sebastian          1074         3298         60         54.966667
# 8           Vir Das          1418         3685         67         55.000000
# 1        Chris Rock          1054         3608         64         56.375000
# 2     Hannah Gadsby          1547         4741         72         65.847222
# 0       Aziz Ansari          1333         4517         65         69.492308
# 9  Whitney Cummings          1385         4127         59         69.949153
# 7   Russell Peters           1213         4850         67         72.388060
# 5     Nate Bargatze          1221         4750         60         79.166667
# 4        Kevin Hart          1181         4827         60         80.450000

# %%
import numpy as np
y_pos = np.arange(len(data_words))

plt.subplot(1, 2, 1)
plt.barh(y_pos, data_unique_sort.unique_words, align='center')
plt.yticks(y_pos, data_unique_sort.comedian)
plt.title('Number of Unique Words', fontsize=20)

plt.subplot(1, 2, 2)
plt.barh(y_pos, data_wpm_sort.words_per_minute, align='center')
plt.yticks(y_pos, data_wpm_sort.comedian)
plt.title('Number of Words Per Minute', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# Observations
#
# Vocabulary:
# 1. Hannah Gadsby and Vir Das have a rich vocabularya and use a lot of words
# 2. Norm Macdonald and Chris Rock have a limited vocabulary
#
# Talking Speed:
# 1. Kevin Hart and Nate Bargatze speak very fast and have a lot of words per minute
# 2. Kenny Sebastian and Norm Macdonald have less words per minute because their set involves a lot of acting

# %% [markdown]
# Amount of profanity

# %%
Counter(words).most_common()
# Out:
# [('like', 10),
#  ('know', 10),
#  ('just', 10),
#  ('im', 10),
#  ('right', 10),
#  ('dont', 10),
#  ('youre', 10),
#  ('thats', 10),
#  ('got', 9),
#  ('people', 8),
#  ('oh', 7),
#  ('going', 7),
#  ('think', 6),
#  ('thing', 6),
#  ('shit', 6),
#  ('fuck', 6),
#  ('yeah', 5),
#  ('say', 5),
#  ('time', 5),
#  ('guy', 5),
#  ('did', 5),
#  ('want', 5),
#  ('cause', 4),
#  ('gonna', 4),
#  ('guys', 4),
#  ('man', 4),
#  ('fucking', 4),
#  ('good', 4),
#  ('said', 4),
#  ('uh', 3),
#  ('okay', 3),
#  ('hes', 3),
#  ('ive', 3),
#  ('need', 3),
#  ('house', 3),
#  ('look', 3),
#  ('theres', 3),
#  ('way', 2),
#  ('white', 2),
#  ('little', 2),
#  ('ok', 2),
#  ('god', 2),
#  ('kids', 2),
#  ('hey', 2),
#  ('make', 2),
#  ('women', 2),
#  ('son', 2),
#  ('goes', 2),
#  ('mean', 2),
#  ('day', 2),
#  ('theyre', 2),
#  ('years', 2),
#  ('indian', 2),
#  ('india', 2),
#  ('stuff', 1),
#  ('really', 1),
#  ('lets', 1),
#  ('gotta', 1),
#  ('black', 1),
#  ('tambourine', 1),
# ...

# %%
data_bad_words = data.transpose()[['fucking', 'fuck', 'shit']]
data_profanity = pd.concat([data_bad_words.fucking + data_bad_words.fuck, data_bad_words.shit], axis=1)
data_profanity.columns = ['f_word', 's_word']
data_profanity
# Out:
#          f_word  s_word
# aziz         10      21
# chris        82      54
# hannah       67       8
# kenny         0      22
# kevin        84      83
# nate          0       0
# norm         31       5
# russell      63      26
# vir          24      44
# whitney      32      24

# %%
plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity.index):
    x = data_profanity.f_word.loc[comedian]
    y = data_profanity.s_word.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x+1.5, y+0.5, full_names[i], fontsize=10)
    plt.xlim(-5, 155) 
    
plt.title('Number of Bad Words Used in Routine', fontsize=20)
plt.xlabel('Number of F Bombs', fontsize=15)
plt.ylabel('Number of S Words', fontsize=15)

plt.show()

# %% [markdown]
# Findings
# 1. Kevin Hart uses a lot of f-words and s-words and hence is very popular among the older audience.
# 2. Comedians like Nate Bargatze is very clean and hence can be watched by all ages

# %% [markdown]
# Idea:
#
# What other word counts do you think would be interesting to compare instead of the f-word and s-word? Create a scatter plot comparing them.

# %%
data_other_words = data.transpose()[['guy', 'guys', 'man']]
data_other = pd.concat([data_other_words.guy + data_other_words.guys, data_other_words.man], axis=1)
data_other.columns = ['guy', 'man']
data_other
# Out:
#          guy  man
# aziz      44   19
# chris      8   89
# hannah     7   12
# kenny     73    8
# kevin     10   41
# nate      42   12
# norm      35   19
# russell   29   10
# vir       28   17
# whitney   73   16

# %%
plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity.index):
    x = data_other.guy.loc[comedian]
    y = data_other.man.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x+1.5, y+0.5, full_names[i], fontsize=10)
    plt.xlim(-5, 155) 
    
plt.title('Number of Man and Guy Used in Routine', fontsize=20)
plt.xlabel('Number of Guy', fontsize=15)
plt.ylabel('Number of Man', fontsize=15)

plt.show()
